# %%
# Init the environment
import sys
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $$
# \begin{align*}
# 3x + 2y + z &= 5 \\
# -x - y + 3z &= 11 \\
# 2x - 3y + z &= 4
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{pmatrix}
# 3 & 2 & 1 \\
# -1 & -1 & 3 \\
# 2 & -3 & 1
# \end{pmatrix}
# \cdot \begin{pmatrix}x\newline y\newline z\end{pmatrix}
# = \begin{pmatrix}5\newline 11\newline 4\end{pmatrix}
# $$

# %% [markdown]
# ---
# ## LB. S. 528
# ### Nr. 1.

# %%
print("a.")
Matrix([[1,2],[4,1]])*Vec2(3,5).to_matrix()
# Out:
# a.
# ⎡13⎤
# ⎢  ⎥
# ⎣17⎦

# %%
print("b.")
Matrix([[0,1],[2,3],[0,1]])*Vec2(2,3).to_matrix()
# Out:
# b.
# ⎡3 ⎤
# ⎢  ⎥
# ⎢13⎥
# ⎢  ⎥
# ⎣3 ⎦

# %%
print("c.")
Matrix([[10,1,3],[0,1,2],[4,3,1]])*Vec3(2,3,1).to_matrix()
# Out:
# c.
# ⎡26⎤
# ⎢  ⎥
# ⎢5 ⎥
# ⎢  ⎥
# ⎣18⎦

# %%
print("d.")
Matrix([[1,0,-7],[-3,4,1],[2,1,0]])*Vec3(-1,2,1).to_matrix()
# Out:
# d.
# ⎡-8⎤
# ⎢  ⎥
# ⎢12⎥
# ⎢  ⎥
# ⎣0 ⎦
