# %%
# Init the environment
import sys
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 247
# ### Nr. 1.
# #### a.
#
# $$
# \begin{align*}
# 2x_1 - 3x_2 - 5x_3 &= -1 \\
# 2x_2 + x_3 &= 0 \\
# 3x_3 &= 6
# \end{align*}
# $$

# %% [markdown]
# $$
# \left(\begin{matrix}2 & -3 & -5 \newline 0 & 2 & 1 \newline 0 & 0 & 3 \end{matrix}\middle|\begin{matrix}-1 \newline 0 \newline 6\end{matrix}\right) \\
# \left(\begin{matrix}2 & 0 & -3,5 \newline 0 & 2 & 1 \newline 0 & 0 & 3 \end{matrix}\middle|\begin{matrix}-1 \newline 0 \newline 6\end{matrix}\right) \\
# \left(\begin{matrix}2 & 0 & -3,5 \newline 0 & 2 & 0 \newline 0 & 0 & 3 \end{matrix}\middle|\begin{matrix}-1 \newline -2 \newline 6\end{matrix}\right) \\
# \left(\begin{matrix}2 & 0 & 0 \newline 0 & 2 & 0 \newline 0 & 0 & 3 \end{matrix}\middle|\begin{matrix}6 \newline -2 \newline 6\end{matrix}\right) \\
# \rightarrow \left(\begin{matrix}1 & 0 & 0 \newline 0 & 1 & 0 \newline 0 & 0 & 1 \end{matrix}\middle|\begin{matrix}3 \newline -1 \newline 2\end{matrix}\right) \\
# $$
#
# $$\Rightarrow x_1 = 3;~ x_2 = -1;~ x_3 = 2$$

# %% [markdown]
# ### Nr. 2.
# #### a.
# $$
# \begin{align*}
# 2x_1 + 4x_2 + 2x_3 &= 7 \\
# 4x_2 + 2x_3 &= 8 \\
# 4x_2 - x_3 &= -1
# \end{align*}
# $$

# %% [markdown]
# $$
# \left(\begin{matrix}2 & 4 & 2 \newline 0 & 4 & 2 \newline 0 & 4 & -1 \end{matrix}\middle|\begin{matrix}7 \newline 8 \newline -1\end{matrix}\right) \\
# \left(\begin{matrix}2 & 0 & 0 \newline 0 & 4 & 2 \newline 0 & 0 & -3 \end{matrix}\middle|\begin{matrix}-1 \newline 8 \newline -9\end{matrix}\right) \\
# \left(\begin{matrix}2 & 0 & 0 \newline 0 & 4 & 0 \newline 0 & 0 & -3 \end{matrix}\middle|\begin{matrix}-1 \newline 2 \newline -9\end{matrix}\right) \\
# \rightarrow \left(\begin{matrix}1 & 0 & 0 \newline 0 & 1 & 0 \newline 0 & 0 & 1 \end{matrix}\middle|\begin{matrix}-0,5 \newline 0,5 \newline 3\end{matrix}\right)
# $$
#
# $$ \Rightarrow x_1 = -0,5;~ x_2 = 0,5;~ x_3 = 3 $$

# %% [markdown]
# ### Nr. 4.
# #### a.
# $$
# \begin{align*}
# 2x_1 - 4x_2 + 5x_3 &= 3 \\
# 3x_1 + 3x_2 + 7x_3 &= 13 \\
# 4x_1 - 2x_2 - 3x_3 &= -1
# \end{align*}
# $$

# %% [markdown]
# $$
# \left(\begin{matrix}2 & -4 & 5 \newline 3 & 3 & 7 \newline 4 & -2 & -3 \end{matrix}\middle|\begin{matrix}3 \newline 13 \newline -1\end{matrix}\right) \\
# \left(\begin{matrix}2 & -4 & 5 \newline 0 & 9 & -0,5 \newline 4 & -2 & -3 \end{matrix}\middle|\begin{matrix}3 \newline 8,5 \newline -1\end{matrix}\right) \\
# \left(\begin{matrix}2 & -4 & 5 \newline 0 & 9 & -0,5 \newline 0 & 6 & -13 \end{matrix}\middle|\begin{matrix}3 \newline 8,5 \newline -7\end{matrix}\right) \\
# \left(\begin{matrix}2 & -4 & 5 \newline 0 & 9 & -0,5 \newline 0 & 9 & -19,5 \end{matrix}\middle|\begin{matrix}3 \newline 8,5 \newline -10,5\end{matrix}\right) \\
# \left(\begin{matrix}2 & -4 & 5 \newline 0 & 9 & -0,5 \newline 0 & 0 & -19 \end{matrix}\middle|\begin{matrix}3 \newline 8,5 \newline -19\end{matrix}\right) \\
# \left(\begin{matrix}2 & -4 & 5 \newline 0 & 9 & -0,5 \newline 0 & 0 & 1 \end{matrix}\middle|\begin{matrix}3 \newline 8,5 \newline 1\end{matrix}\right) \\
# \left(\begin{matrix}2 & -4 & 5 \newline 0 & 1 & 0 \newline 0 & 0 & 1 \end{matrix}\middle|\begin{matrix}3 \newline 1 \newline 1\end{matrix}\right) \\
# \left(\begin{matrix}1 & 0 & 0 \newline 0 & 1 & 0 \newline 0 & 0 & 1 \end{matrix}\middle|\begin{matrix}1 \newline 1 \newline 1\end{matrix}\right)
# $$
#
# $$\rightarrow x_1 = 1;~ x_2 = 1;~ x_3 = 1$$

# %% [markdown]
# ## IQB
# ### Nr. 1.
# $$
# \begin{align*}
# 2x + z &= 0 \\
# -y + 2z &= 0 \\\
# 2y + bz &= 1
# \end{align*}
# $$

# %% [markdown]
# $$
# \left(\begin{matrix}2 & 0 & 1 \newline 0 & -1 & 2 \newline 0 & 2 & b \end{matrix}\middle|\begin{matrix}0 \newline 0 \newline 1\end{matrix}\right) \\
# \left(\begin{matrix}2 & 0 & 1 \newline 0 & -1 & 2 \newline 0 & 0 & b+4 \end{matrix}\middle|\begin{matrix}0 \newline 0 \newline 1\end{matrix}\right) \\
# \left(\begin{matrix}2 & 0 & 1 \newline 0 & -1 & 2 \newline 0 & 0 & 1 \end{matrix}\middle|\begin{matrix}0 \newline 0 \newline \frac1{b+4}\end{matrix}\right)
# $$
#
# $$
# \begin{align*}
# \rightarrow z &= \frac1{b+4} \\
# \rightarrow 2x + \frac1{b+4} &= 0 \rightarrow x = -\frac1{2b + 8} \\
# \rightarrow -y + \frac2{b+4} &= 0 \rightarrow y = \frac2{b+4}
# \end{align*}
# $$
#
# Es gibt keine Lösung für $b = -4$. Für alle $b \in \mathbb R \backslash \{-4\}$ gibt es genau eine Lösung.

# %% [markdown]
# ### 2.
# $$
# \begin{align*}
# x + 2y &= a \\
# -y + 4z &= 2 \\
# (4-a^2)z &= 2+a
# \end{align*}
# $$
#
# $\displaystyle a \colonequals 0 $

# %% [markdown]
# #### a.
# $$
# \left(\begin{matrix}1 & 2 & 0 \newline 0 & -1 & 4 \newline 0 & 0 & 4 \end{matrix}\middle|\begin{matrix}0 \newline 2 \newline 2\end{matrix}\right) \\
# \left(\begin{matrix}1 & 0 & 0 \newline 0 & 1 & 0 \newline 0 & 0 & 1 \end{matrix}\middle|\begin{matrix}0 \newline 0 \newline 0,5\end{matrix}\right)
# $$
#
# $$ \rightarrow x = 0;~ y = 0;~ z = 0,5 $$

# %% [markdown]
# #### b.
# $$
# \left(\begin{matrix}1 & 2 & 0 \newline 0 & -1 & 4 \newline 0 & 0 & 4-a^2 \end{matrix}\middle|\begin{matrix}a \newline 2 \newline 2+a\end{matrix}\right) \\
# \left(\begin{matrix}1 & 2 & 0 \newline 0 & -1 & a^2 \newline 0 & 0 & (2+a)(2-a) \end{matrix}\middle|\begin{matrix}a \newline a \newline 2+a\end{matrix}\right) \\
# \left(\begin{matrix}1 & 2 & 0 \newline 0 & -1 & a^2 \newline 0 & 0 & 2-a \end{matrix}\middle|\begin{matrix}a \newline a \newline 1\end{matrix}\right) \\
# $$
