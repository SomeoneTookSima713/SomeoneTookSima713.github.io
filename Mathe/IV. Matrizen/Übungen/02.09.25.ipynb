# %%
# Init the environment
import sys
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ### 1.
# $$
# \begin{align*}
# \begin{pmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# -1 & 2 & 4
# \end{pmatrix} \cdot
# \begin{pmatrix}
# 3 & 1 \\
# 2 & -1 \\
# -2 & 0
# \end{pmatrix}
# &= \begin{pmatrix}
# 1 & -1 \\
# 10 & -1 \\
# -7 & -3
# \end{pmatrix}
# \end{align*}
# $$

# %% [markdown]
# ### 2.
# $$
# \begin{align*}
# \begin{pmatrix}
# 2 & 1 \\
# 4 & -3
# \end{pmatrix} \cdot
# \begin{pmatrix}
# 1 & 5 & 4 \\
# 7 & 0 & -2
# \end{pmatrix}
# &= \begin{pmatrix}
# 9 & 10 & 6 \\
# -17 & 20 & 22
# \end{pmatrix}
# \end{align*}
# $$

# %% [markdown]
# ## LB. S. 534
# ### Nr. 1.

# %%
(
    Matrix([[2,1],[3,2],[0,5]])*Matrix([[2,1,3],[0,3,2]]),
    Matrix([[2,1,3],[0,3,2]])*Matrix([[2,1],[3,2],[0,5]]),
    Matrix([[0,1,2],[4,2,0],[0,3,1]])*Matrix([[3,1,1],[1,3,1],[4,0,2]])
)
# Out:
# ⎛⎡4  5   8 ⎤           ⎡9   3   5⎤⎞
# ⎜⎢         ⎥  ⎡7  19⎤  ⎢         ⎥⎟
# ⎜⎢6  9   13⎥, ⎢     ⎥, ⎢14  10  6⎥⎟
# ⎜⎢         ⎥  ⎣9  16⎦  ⎢         ⎥⎟
# ⎝⎣0  15  10⎦           ⎣7   9   5⎦⎠

# %% [markdown]
# ### Nr. 2.
# $$
# \begin{align*}
# A &= \begin{pmatrix}
# 1 & 3 \\
# 5 & 7 \\
# 9 & 11
# \end{pmatrix} \\
# B &= \begin{pmatrix}
# 2 & 4 & 6 \\
# 8 & 10 & 12
# \end{pmatrix}
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# A \cdot B &= \begin{pmatrix}
# 26 & 34 & 42 \\
# 66 & 90 & 114 \\
# 106 & 146 & 186
# \end{pmatrix} \\
# B \cdot A &= \begin{pmatrix}
# 76 & 100 \\
# 166 & 226
# \end{pmatrix} \\
# &\neq A \cdot B
# \end{align*}
# $$

# %% [markdown]
# ### Nr. 3.
# $$
# \begin{align*}
# A^2 &= \begin{pmatrix}
# 1 & 5 \\
# 0 & 0
# \end{pmatrix} = A \\
# A^3 &= A^2 \cdot A = A^2 = A \\
# B^2 &= \begin{pmatrix}
# 2 & 2 \\
# 2 & 2
# \end{pmatrix} \\
# C^2 &= \begin{pmatrix}
# 9 & 0 \\
# 0 & 9
# \end{pmatrix} \\
# E^2 &= \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix}
# \end{align*}
# $$
