# %%
# Init the environment
import sys
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 346
# ### Nr. 1.
# #### b.
# $$
# \begin{align*}
# R&(-2|-6|1) \\
# g: \overrightarrow{ x } &= \begin{pmatrix}5\newline 9\newline 1\end{pmatrix} + t \begin{pmatrix}3\newline 2\newline 2\end{pmatrix} \\
# \text{Abst}(R; g) &= \left| \begin{pmatrix}5\newline 9\newline 1\end{pmatrix} - \begin{pmatrix}-2\newline -6\newline 1\end{pmatrix} - \frac{ \begin{pmatrix}3\newline 2\newline 2\end{pmatrix} }{ \left| \begin{pmatrix}3\newline 2\newline 2\end{pmatrix} \right|^2 } \left( \begin{pmatrix}3\newline 2\newline 2\end{pmatrix} \circ \left(\begin{pmatrix}5\newline 9\newline 1\end{pmatrix} - \begin{pmatrix}-2\newline -6\newline 1\end{pmatrix} \right)\right) \right| \\
# &= 11
# \end{align*}
# $$

# %% [markdown]
# ### Nr. 3.
# #### a.
# $$
# \begin{align*}
# \overrightarrow{ OR } &= \begin{pmatrix}-5\newline 6\newline 8\end{pmatrix} + 0 \begin{pmatrix}1\newline 0\newline -2\end{pmatrix} \\
# \rightarrow R&(-5|6|8) \\
# g: \overrightarrow{ x } &= \begin{pmatrix}6\newline 4\newline 1\end{pmatrix} + t \begin{pmatrix}-1\newline 0\newline 2\end{pmatrix} \\
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# P&(6|4|1) \\
# \overrightarrow{ RP } &= \begin{pmatrix}11\newline -2\newline -7\end{pmatrix} \\
# \text{Abst}(R; g) &= \left| \overrightarrow{ RP } - \frac{ \begin{pmatrix}-1\newline 0\newline 2\end{pmatrix} }{ \left| \begin{pmatrix}-1\newline 0\newline 2\end{pmatrix} \right|^2 } \left( \begin{pmatrix}-1\newline 0\newline 2\end{pmatrix} \circ \overrightarrow{ RP } \right) \right| \\
# &= 7
# \end{align*}
# $$
