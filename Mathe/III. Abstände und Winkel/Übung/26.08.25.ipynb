# %%
# Init the environment
import sys
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ### 1.
# #### c.
# $$
# \begin{align*}
# \overrightarrow{ u } &= \begin{pmatrix}1\newline 2\newline -1\end{pmatrix} \\
# S&(2|2|8) \\
# E: x + y &= 10 \\
# g: \overrightarrow{ x } &= \overrightarrow{ OS } + t \overrightarrow{ u } \\
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# x_S + tx_u + y_S + ty_u &= 10 \\
# \rightarrow t &= \frac{10 - x_S - y_S}{x_u + y_u} \\
# \rightarrow \overrightarrow{ OS' } &= \overrightarrow{ OS } + t \overrightarrow{ u } \\
# &= \begin{pmatrix}x_S + \frac{10 - x_S - y_S}{x_u + y_u} x_u\newline y_S + \frac{10 - x_S - y_S}{x_u + y_u} y_u\newline z_S + \frac{10 - x_S - y_S}{x_u + y_u} z_u\end{pmatrix}
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# \rightarrow S'&(4|6|6)
# \end{align*}
# $$
