# %%
# Init the environment
import sys
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ### 1.
# $$
# \begin{align*}
# P&(-1|7|2) \\
# E: x_1 + 3x_2 &= 0
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# -1 + 3 \cdot 7 &= 20 \\
# &\neq 0 \\
# \rightarrow P &\notin E
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# \overrightarrow{ d } &~-~\text{Vektor von Punkt }P\text{ zum nächstgelegenen Punkt auf }E \\
# \overrightarrow{ d } &= - \overrightarrow{ OP } \circ \frac{ \begin{pmatrix}1\newline 3\newline 0\end{pmatrix} }{ \left| \begin{pmatrix}1\newline 3\newline 0\end{pmatrix} \right|^2 } \cdot \begin{pmatrix}1\newline 3\newline 0\end{pmatrix} \\
# \end{align*}
# $$

# %%
d = Vec3(1,3,0) * (Vec3(1, -7, -2)*Vec3(1,3,0)/(Vec3(1,3,0).magnitude**2))
Eq(Symbol('\\overrightarrow{d}'), (d.values[0], d.values[1], d.values[2]))
# Out:
# \overrightarrow{d} = (-2, -6, 0)

# %% [markdown]
# $$
# \begin{align*}
# \overrightarrow{ OP' } &= \overrightarrow{ OP } + 2 \overrightarrow{ d } \\
# &= \begin{pmatrix}-1\newline 7\newline 2\end{pmatrix} + 2 \begin{pmatrix}-2\newline -6\newline 0\end{pmatrix} \\
# &= \begin{pmatrix}-5\newline -5\newline 2\end{pmatrix} \\
# \Rightarrow P'&(-5|-5|2)
# \end{align*}
# $$

# %% [markdown]
# ### 2.
# $$
# \begin{align*}
# P&(1|2|3) \\
# Q&(7|2|11)
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# \overrightarrow{ p } &= \frac{ \overrightarrow{ OP } + \overrightarrow{ OQ } }{2} \\
# &= \begin{pmatrix}4\newline 2\newline 7\end{pmatrix} \\
# \overrightarrow{ n } &= \overrightarrow{ PQ } \\
# &= \begin{pmatrix}6\newline 0\newline 8\end{pmatrix} \\
# E: 6x_1 + 8x_3 &= 80
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# \overrightarrow{ OR } &= \overrightarrow{ OP } + \frac12 \overrightarrow{ QP } \\
# \rightarrow R&(-2|2|-1)
# \end{align*}
# $$
