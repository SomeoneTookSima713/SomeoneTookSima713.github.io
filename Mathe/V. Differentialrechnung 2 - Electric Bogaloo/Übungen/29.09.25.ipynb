# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ### Bilden Sie eine Stammfunktion

# %% [markdown]
# $$
# \begin{align*}
# \text{a. }&& f(x) &= 3x &\rightarrow F(x) &= \frac32x^2 \\
# \text{b. }&& f(x) &= 0,5x^2 &\rightarrow F(x) &= \frac16x^3 \\
# \text{c. }&& f(x) &= \sqrt2x &\rightarrow F(x) &= \frac{\sqrt2}2x^2 \\
# \text{d. }&& f(x) &= 0 &\rightarrow F(x) &= 0 \\
# \text{e. }&& f(x) &= 2x^3 &\rightarrow F(x) &= \frac12x^4 \\
# \text{f. }&& f(x) &= 2(x-4) &\rightarrow F(x) &= x^2-8x \\
# \text{g. }&& f(x) &= \frac{x^2 - 2}{4} &\rightarrow F(x) &= \frac1{12}x^3 - \frac12x \\
# \text{h. }&& f(x) &= \frac{3x-3}{-2} &\rightarrow F(x) &= -\frac34x^2 + \frac32x \\
# \text{i. }&& f(x) &= 2\pi x^2 - (x^2)^2 &\rightarrow F(x) &= \frac23\pi x^3 - \frac15x^5 \\
# \text{j. }&& f(x) &= (-2x)^3 - 2x^2 &\rightarrow F(x) &= -2x^4 - \frac23x^3
# \end{align*}
# $$
