# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# Berechnen Sie $\displaystyle \int_0^22xdx $ und $\displaystyle \int_2^0 2xdx $. Was stellen Sie fest?

# %% [markdown]
# $$
# \begin{align*}
# \int2xdx &= F(x) + c, c \in \mathbb R \\
# \rightarrow F(x) &= x^2 \\
# \int_0^22xdx &= F(2) - F(0) \\
# &= 4 \\
# \int_0^22xdx &= F(0) - F(2) \\
# &= -4 \\
# \end{align*}
# $$
#
# $$ \Rightarrow \int_a^bf(x)dx = -\int_b^af(x)dx $$

# %% [markdown]
# ## LB. S. 152

# %% [markdown]
# ### Nr. 11.

# %% [markdown]
# $$
# \begin{align*}
# f(x) &= \frac19x^2 \\
# \int_0^3f(x)dx &= F(3)-F(0) \\
# F(x) &= \frac1{27}x^3 \\
# \int_0^3f(x)dx &= 1
# \end{align*}
# $$
#
# (1) Das Ergebnis repräsentiert die vom Graphen der Funktion $f$ und der $x$-Achse eingeschlossene Fläche über dem Intervall $[0;3]$.
#
# (2) Das Ergebnis repräsentiert den innerhalb von $3$ Sekunden zurückgelegten Weg des Autos in Metern.
#
# (3) Das Ergebnis repräsentiert das Produkt des produzierten Benzins in tausend Tonnen und der dafür benötigten Zeit in Stunden.

# %% [markdown]
# ### Nr. 13.
# $$
# \begin{align*}
# f_1(x) &= x^3 \\
# f_2(x) &= x^5 \\
# f_3(x) &= x^7
# \end{align*}
# $$

# %% [markdown]
# ---

# %% [markdown]
# ### Berechnen Sie den Wert der Variablen.

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# \int_0^bx^2dx &= 9 \\
# \rightarrow F(x) &= \frac13x^3 \\
# F(b) - F(0) &= 9 \\
# \rightarrow b &= \sqrt[3]{27} \\
# &= 3
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# \int_a^5x^2dx &= 63 \\
# \rightarrow 63 &= \left[\frac13x^3\right]_a^5 \\
# &= \frac{125}{3} - \frac{a^3}3 \\
# 125-189 &= a^3 \\
# &= -64 \\
# \rightarrow a &= 4
# \end{align*}
# $$

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# \int_1^b 2x^3dx &= 40 \\
# \rightarrow 40 &= \left[\frac12x^4\right]_1^b \\
# &= \frac12b^4 - \frac12 \\
# 81 &= b^4 \\
# \rightarrow b &= \pm3
# \end{align*}
# $$

# %% [markdown]
# #### d.
# $$
# \begin{align*}
# \int_0^1 kx^3dx &= 7 \\
# k\int_0^1x^3dx &= 7 \\
# \rightarrow k &= 28
# \end{align*}
# $$

# %% [markdown]
# ## LB. S. 152
# ### Nr. 14.

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# \int_0^zxdx &= 18 \\
# \rightarrow z &= 6
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# \int_1^z 4xdx &= 30 \\
# \rightarrow 2z^2 - 2 &= 30 \\
# \rightarrow z &= 4
# \end{align*}
# $$

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# \int_z^{10} 2xdx &= 19 \\
# \rightarrow 100 - z^2 &= 19 \\
# \rightarrow z &= 9
# \end{align*}
# $$

# %% [markdown]
# #### d.
# $$
# \begin{align*}
# \int_0^{2z}0,4dx &= 8 \\
# \rightarrow z &= 10
# \end{align*}
# $$
