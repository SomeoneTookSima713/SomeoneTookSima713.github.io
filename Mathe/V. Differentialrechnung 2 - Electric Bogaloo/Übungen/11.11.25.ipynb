# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 164
# ### Nr. 4.

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# f(x) &= \frac12x \\
# g(x) &= -x^2+4 \\
# I &= [-1;1] \\
# A &= \int_{-1}^1\left( -x^2 - \frac12x + 4 \right)dx \\
# &= \left[ -\frac13x^3 - \frac14x^2 + 4x \right]_{-1}^1 \\
# &= \frac{41}{12} + \frac{47}{12} \\
# &= \frac{22}{3}
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# f(x) &= x^3 \\
# g(x) &= x \\
# I &= [0;1] \\
# A &= \int_0^1 \left(x - x^3\right)dx \\
# &= \left[ \frac12x^2 - \frac14x^4 \right]_0^1 \\
# &= \frac14
# \end{align*}
# $$

# %% [markdown]
# ### Nr. 5.

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# f(x) &= x^2 \\
# g(x) &= -x^2 + 4x \\
# f(x) &\overset!= g(x) \\
# \rightarrow x &= -1 \pm 1 \\
# \rightarrow I &= [-2;0] \\
# A &= \int_{-2}^0 (f(x) - g(x))dx \\
# &= \left[ \frac23x^3  - 2x^2 \right]_{-2}^0 \\
# &= \frac{16}3
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# f(x) &= -x^{-2} \\
# g(x) &= \frac52x - \frac{21}4 \\
# f(x) &\overset!= g(x) \\
# \rightarrow \frac52x - \frac{21}4 + x^{-2} &= 0 \\
# \frac52x^3 - \frac{21}4x^2 + 1 &= 0 \\
# \rightarrow x &\in \left\{ -\frac25; \frac12; 2 \right\} \\
# \rightarrow A &= \left| \int_{0,5}^{2}(f(x)-g(x))dx \right| \\
# &= \left| \left[ x^{-1} - \frac54x^2 + \frac{21}4x \right]_{\frac12}^{2} \right| \\
# &= \frac{27}{16}
# \end{align*}
# $$

# %% [markdown]
# ## LB. S. 177

# %% [markdown]
# ### Nr. 7.
# $$
# \begin{align*}
# f(x) &= -5x^2 + 0,8\\
# A_G &= 1 \text{ m}^2 - 1 \text{ m}^2 \cdot \int_{-0,4}^{0,4}f(x)dx \\
# &= 1 \text{ m}^2 - 1 \text{ m}^2 \cdot \left[ -\frac53x^3 + 0,8x \right]_{-0,4}^{0,4} \\
# &= \frac{43}{75} \text{ m}^2 \\
# V &= A_G \cdot 1 \text{ m} \\
# &\approx 0,573 \text{ m}^3 \\
# m &= V \cdot 2,3 \frac{\text t}{\text m^3} \\
# &\approx 1,319 \text{ t}
# \end{align*}
# $$

# %% [markdown]
# ### Nr. 9.
# #### a.

# %% [markdown]
# $$
# \begin{align*}
# f(x) &= 0,5x^2 \\
# P &(3|4,5) \\
# f(x) &\overset!= 0 \\
# \rightarrow x_0 &= 0 \\
# f'(x) &= x \\
# f'(3) &= 3 \\
# &= m \\
# t: y &= m(x-3) + 4,5 \\
# &= 3x - 4,5 \\
# &\overset!= 0\\
# \rightarrow x_1 &= 1,5 \\
# x_2 &= 3 \\
# \Rightarrow A &= \int_0^{1,5} f(x)dx + \int_{1,5}^3 (f(x) - y_t)dx \\
# &= \frac98
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# f(x) &= x^{-2} - \frac14 \\
# P &(0,5|3,75) \\
# f(x) &\overset!= 0 \\
# \rightarrow x_{0,1} &= \pm2 \\
# f'(x) &= -2x^{-3} \\
# f'(0,5) &= -16 \\
# &= m \\
# t: y &= m(x - 0,5) + 3,75 \\
# &= -16x + 11,75 \\
# &\overset != 0 \\
# \rightarrow x_2 &= \frac{47}{64} \\
# \rightarrow A &= \int_{0,5}^{\frac{47}{64}}(f(x)-y_t)dx + \int_{\frac{47}{64}}^2f(x)dx \\
# &\approx 0,686
# \end{align*}
# $$
