# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 155
# ### Nr. 1.

# %% [markdown]
# $$
# \begin{align*}
# f_a(x) &= 0,5x^3 &\rightarrow F_a(x) &= \frac18x^4 \\
# f_b(x) &= \frac14x^{-2} &\rightarrow F_b(x) &= -\frac1{4}x^{-1} \\
# f_c(x) &= \frac2{5x^2} &\rightarrow F_c(x) &= -\frac25x^{-1} \\
# f_d(x) &= (2x+2)^3 &\rightarrow F_d(x) &= \frac18(2x+2)^4 \\
# f_e(x) &= 2\sin(x+1) &\rightarrow F_e(x) &= -2\cos(x+1) \\
# f_f(x) &= \cos(3x) &\rightarrow F_f(x) &= \frac13\sin(3x) \\
# f_g(x) &= x+2\sin(2x) &\rightarrow F_g(x) &= \frac12x^2 - \cos(2x) \\
# f_h(x) &= \cos(4x - \pi) &\rightarrow F_h(x) &= \frac14\sin(4x - \pi) \\
# f_i(x) &= \frac13e^{x+5} &\rightarrow F_i(x) &= \frac13e^{x+5} \\
# f_j(x) &= 1+e^{0,5x} &\rightarrow F_j(x) &= x + 2e^{0,5x} \\
# f_k(x) &= e^{\frac23x+1} &\rightarrow F_k(x) &= \frac32e^{\frac23x+1} \\
# f_l(x) &= \frac52e^{2x-2} &\rightarrow F_l(x) &= \frac54e^{2x-2}
# \end{align*}
# $$

# %% [markdown]
# ### Nr. 2.

# %% [markdown]
# $$
# \begin{align*}
# f_a(x) &= \frac5x &\rightarrow F_a(x) &= 5\ln\left|x\right|\text{sgn}~x \\
# f_b(x) &= 3\cdot \frac1{x+5} &\rightarrow F_b(x) &= 3\ln\left|x+5\right|\cdot\text{sgn}(x+5) \\
# f_c(x) &= \frac{-1}{2x} &\rightarrow F_c(x) &= -\frac12\ln\left|x\right|\cdot\text{sgn}(x) \\
# f_d(x) &= \frac1{2x-3} &\rightarrow F_d(x) &= \frac12\ln\left| 2x-3 \right| \cdot \text{sgn}(2x-3)
# \end{align*}
# $$

# %% [markdown]
# ## S. 156
# ### Nr. 12.

# %% [markdown]
# $$
# \begin{align*}
# f_a(x) &= \frac{x^2+2x}{x^4} \\
# &= x^{-2} + 2x^{-3} &\rightarrow F_a(x) &= -x^{-1} - x^{-2} \\
# f_b(x) &= \frac{x^3+1}{2x^2} \\
# &= \frac12x + \frac12x^{-2} &\rightarrow F_b(x) &= \frac14x^2 - \frac12x^{-1} \\
# f_c(x) &= \frac{1+x+x^3}{3x^3} \\
# &= \frac13x^{-3} + \frac13x^{-2} + \frac13 &\rightarrow F_c(x) &= -\frac16x^{-2} - \frac13x^{-1} + \frac13x \\
# f_d(x) &= \frac{(2x+1)^2-1}{x} \\
# &= 4x + 4 &\rightarrow F_d(x) &= 2x^2 + 4x
# \end{align*}
# $$
