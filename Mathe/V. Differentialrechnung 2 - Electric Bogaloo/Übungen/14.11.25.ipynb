# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## IQB-Aufgaben
# ### 1.
# $$
# \begin{align*}
# f_a(x) &= ax^3 + ax^2 &&,\,a \in \mathbb R^+
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# f_a(1) &= 6 \\
# \rightarrow 2a &= 6 \\
# \rightarrow a &= 3
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# f_a(x_N) &= 0 \\
# \rightarrow x_N^2\left( ax_N + a \right) &= 0 \\
# \rightarrow x_N &\in \left\{ -1; 0 \right\} \\
# \rightarrow A &= \int_{-1}^0 f_a(x)dx \\
# &= \left[ \frac14ax^4 + \frac13ax^3 \right]_{-1}^0 \\
# &= \frac13a - \frac14a \\
# &= \frac{a}{12}
# \end{align*}
# $$

# %% [markdown]
# ### 2.

# %% [markdown]
# #### a.
# $\displaystyle T(2|-1) $

# %% [markdown]
# ### 3.
# $$
# \begin{align*}
# \exists f,g &: D_f, D_g = \mathbb R_0^+,\, \left( g(f(x)) = x \right) \forall x\in\mathbb R_0^+ \\
# \exists x_S\in\mathbb R_0^+ &: f(x_S) = g(x_S)
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# \int_0^{x_S}(g(x)-f(x))dx &= 2\int_0^{x_S}(x-f(x))dx \\
# \int_0^{x_S}(g(x)-f(x))dx &= 2\int_0^{x_S}(g(f(x))-f(x))dx \\
# \int_0^{x_S}g(x)dx + \int_0^{x_S}f(x)dx &= 2\int_0^{x_S}g(f(x))dx \\
# \end{align*}
# $$
