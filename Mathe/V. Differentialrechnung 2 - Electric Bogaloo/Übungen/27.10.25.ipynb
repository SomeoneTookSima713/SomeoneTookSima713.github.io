# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## Berechnen Sie das Integral.

# %% [markdown]
# a. $\displaystyle \int_1^4 xdx = \left[ \frac12x^2 \right]_1^4 = \frac{14}2 $
#
# b. $\displaystyle \int_{-2}^0(2+x)^2dx = \left[4x + 2x^2 + \frac13x^3\right]_{-2}^0 = \frac83 $
#
# c. $\displaystyle \int_{-2}^4x^3dx = \left[\frac14x^4\right]_{-2}^4 = 60 $
#
# d. $\displaystyle \int_{0,5}^2 \frac{1}{x^2}dx = \left[-\frac1x\right]_{0,5}^2 = \frac32 $
#
# e. $\displaystyle \int_{-4}^{-2} (1-3x^2)dx = \left[ x - x^3 \right]_{-4}^{-2} = -54 $
#
# f. $\displaystyle \int_1^2(x-\frac1{x^2})dx = \left[\frac12x^2+\frac1x\right]_1^2 = 1 $
#
# g. $\displaystyle \int_1^6\frac1{\sqrt x}dx = \left[ 2\sqrt x \right]_1^6 = 2\sqrt6-2 $
#
# h. $\displaystyle \int_0^4(\frac14x^2 + 2)dx = \left[\frac1{12}x^3 + 2x\right]_0^4 = \frac{40}3 $
#
# i. $\displaystyle \int_0^\pi\sin xdx = \left[-\cos x\right]_0^\pi = 2 $
#
# j. $\displaystyle \int_{-3}^52e^{4x}dx = \left[\frac12e^{4x}\right]_{-3}^5 = \frac12e^{20} - \frac12e^{-12} = \frac{e^{32}-1}{2e^{12}} $
