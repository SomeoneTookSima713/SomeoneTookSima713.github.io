# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 147/148

# %% [markdown]
# ### Nr. 3.
# a. $\displaystyle \left[ \frac13x^3 \right]_0^2 \approx 2,667 $
#
# b. $\displaystyle \left[ \frac13x^3-x \right]_0^2 \approx 0,667 $
#
# c. $\displaystyle \left[ \frac14x^4 \right]_{-1}^1 = 0 $
#
# d. $\displaystyle \left[ \sin x \right]_{-\frac\pi2}^{\frac\pi2} = 2 $
#
# e. $\displaystyle \left[ e^x-2x \right]_0^1 \approx -0,282 $

# %% [markdown]
# ### Nr. 4.
# $$
# \begin{align*}
# A_1 &= \int_1^4\frac1x dx \\
# &= \left[ \ln x \right]_1^4 \\
# &= \ln 4 \\
# A_2 &= \int_{-\sqrt5}^{\sqrt5} \left( -\frac12x^2 + 2,5 \right)dx \\
# &= \left[ -\frac16x^3 + 2,5x \right]_{-\sqrt5}^{\sqrt5} \\
# A_3 &= \int_{-4}^{-1}\left( \frac1{x^2}-1 \right)dx \\
# &= \left[ -\frac1x - x \right]_{-4}^{-1} \\
# &= -\frac{13}4 \\
# \end{align*}
# $$

# %%
func_a2 = lambda x : x**3*Rational(-1,6) + Rational(5,2)*x

Eq(Symbol("A_2"), func_a2(sqrt(5))-func_a2(-sqrt(5)))
# Out:
#      10⋅√5
# A₂ = ─────
#        3

# %% [markdown]
# ### Nr. 7.
# a. positiv, weil alle Funktionswerte positiv
#
# b. negativ, weil alle Funktionswerte negativ
#
# c. negativ, weil mehr Funktionswerte negativ als positiv und alle positiven Funktionswerte einem negativen Funktionswert eindeutig zugeordnet werden können und trotzdem noch negative Funktionswerte übrigbleiben
#
# d. positiv, weil alle Funktionswerte positiv
#
# e. null, weil ganze Periode der Funktion besteht aus zwei identischen Hälften, die an der x-Achse gespiegelt sind

# %% [markdown]
# ### Nr. 11.
# $$
# \begin{align*}
# b(t) &= 10^6e^{-0,1t} ~,\,t\text{ in a},\, b \text{ in }\frac{\text{t}}{\text{a}} \\
# m &= \int_0^{10}b(t)dt \\
# &= \left[ -10^7e^{-0,1t} + C \right]_0^{10} \\
# &= -10^7e^{-1} + C \\
# C &= 4000000 \\
# \end{align*}
# $$
