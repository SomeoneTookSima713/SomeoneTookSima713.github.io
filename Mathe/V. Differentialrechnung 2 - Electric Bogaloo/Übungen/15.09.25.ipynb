# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# Gegeben ist das Geschwindigkeit-Zeit-Diagramm eines Spielzeugautos auf einer geraden Strecke.

# %%
plt.plot([0, 4, 6, 6, 7], [0.2, 0.2, 0, -0.1, -0.1])
plt.ylabel("v in m/s")
plt.xlabel("t in s")
# plt.axis((0, 1000, 0, 0.051))
plt.grid(true, "major", "both", color='#888888', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Bestimmen Sie den Abstand zum Startpunkt für das Intervall
# $$
# \begin{align*}
# \text a.&& [0 \text{ s}; 4 \text{ s}]&: 4 \text{ s} \cdot 0,2 \frac{\text m}{\text s} = 0,8 \text{ m} \\
# \text b.&& [4 \text{ s}; 6 \text{ s}]&: \frac12 \cdot 2 \text{ s} \cdot 0,2 \frac{\text m}{\text s} = 0,2 \text{ m} \\
# \text c.&& [6 \text{ s}; 7 \text{ s}]&: 1 \text{ s} \cdot (-0,1) \frac{\text m}{\text s} = -0,1 \text{ m} \\
# \text d.&& [0 \text{ s}; 7 \text{ s}]&: 0,8 \text{ m} + 0,2 \text{ m} - 0,1 \text{ m} = 0,9 \text{ m} \\
# \end{align*}
# $$

# %% [markdown]
# ## LB. S. 143-144 Nr. 1-6
# ### Nr. 1.
# $\displaystyle 5 \text{ m},~ 50 \text{ m},~ 2,5 \text{ m} $
#
# ### Nr. 2.
# 2 Stunden: 502 Liter \
# 4 Stunden: 2002 Liter \
# 6 Stunden: 2502 Liter \
# 8 Stunden: 2 Liter
#
# ### Nr. 3.
# #### a.
# Eine Flächeneinheit beschreibt in diesem Zusammenhang eine Million Kubikmeter an Wasser, die in den Wasserspeicher rein- oder aus ihn herausfließen.
#
# #### b.
# Im Intervall $\displaystyle [2 \text{ h}; 4 \text{ h}] $ nimmt das Wasser am schnellsten zu, ist bei $\displaystyle 6 \text{ h} $ maximal, nimmt am schnellsten im Intervall $\displaystyle [8 \text{ h}; 10 \text{ h}] $ ab und ist bei $\displaystyle 12 \text{ h} $ minimal. Nach zwölf Stunden wiederholt sich der abgebildete Graph, da der Sachzusammenhang einen periodischen Vorgang beschreibt und eine Periode abgebildet ist.
#
# #### c.
# Dadurch ist die Fläche 25% größer.
#
# ### Nr. 4.
# #### a.
# Zeitpunkt in $\text s$|Höhe in $\text m$
# -|-
# $ 10 $|$ 410 $
# $ 20 $|$ 430 $
# $ 30 $|$ 440 $
# $ 40 $|$ 435 $
#
# #### b.
# Das Flugzeug fliegt zum Zeitpunkt $t = 60 \text{ s}$ auf $\displaystyle 395 \text{ m} $ Höhe.

# %% [markdown]
# ### Nr. 5.

# %%
plt.plot([0,2,2,6], [3,3,0,0])
plt.ylabel("y")
plt.xlabel("x")
# plt.axis((0, 1000, 0, 0.051))
plt.grid(true, "major", "both", color='#888888', linestyle='--', linewidth=0.5)
plt.show()

plt.plot([0,3,3,6], [2,2,0,0])
plt.ylabel("y")
plt.xlabel("x")
# plt.axis((0, 1000, 0, 0.051))
plt.grid(true, "major", "both", color='#888888', linestyle='--', linewidth=0.5)
plt.show()

plt.plot([0,6], [1,1])
plt.ylabel("y")
plt.xlabel("x")
# plt.axis((0, 1000, 0, 0.051))
plt.grid(true, "major", "both", color='#888888', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ### 6.

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# P(90 \text{ min}) &= \frac12 \cdot 40 \text{ min} \cdot 100 \frac{\text{Personen}}{\text{min}} \\
# &= 2000 \text{ Personen} \\
# P(70 \text{ min}) &= P(90 \text{ min}) + \frac34 \cdot 20 \text{ min} \cdot 200 \frac{\text{Personen}}{\text{min}} - 20 \text{ min} \cdot 200 \frac{\text{Personen}}{\text{min}} \\
# &= 1000 \text{ Personen}
# \end{align*}
# $$

# %% [markdown]
# #### b.
# Die Warteschlange ist 30 Minuten vor Einlass am längsten. Zu diesem Zeitpunkt warten $\displaystyle P(70 \text{ min}) + 30 \text{ min} \cdot 50 \frac{\text{Personen}}{\text{min}} = 2500 $ Personen auf den Einlass.
