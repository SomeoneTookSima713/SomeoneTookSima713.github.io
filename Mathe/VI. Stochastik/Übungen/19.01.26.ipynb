# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 463
# ### Nr. 2.

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# \binom 40 &= 1 \\
# \binom 41 &= 4 \\
# \binom 42 &= 6 \\
# \binom 43 &= 4 \\
# \binom 44 &= 1 \\
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $r$|$P(X=r)$
# -|-
# $ 0 $|$ \frac{16}{81} $
# $ 1 $|$ \frac{32}{81} $
# $ 2 $|$ \frac{8}{27} $
# $ 3 $|$ \frac{8}{81} $
# $ 4 $|$ \frac{1}{81} $

# %% [markdown]
# #### c.

# %%
plt.plot([n for n in range(5)], [binomial(4, i)*Rational(1,3)**i*Rational(2,3)**(4-i) for i in range(5)])
plt.ylabel("P(X=r)")
plt.xlabel("r")
# plt.axis((0, 1e-32, 0, 1))
plt.grid(true, "major", "both", color='#888888', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# $$
# \begin{align*}
# n &:= 10 \\
# p &:= \frac14
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# P(X=0) &= \binom n0 \cdot p^0 \cdot (1-p)^{n-0} \\
# &= (1-p)^n \\
# &= \frac{59049}{1048576} \\
# &\approx 5,63\%
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# P(X=3) &= \binom n3 \cdot p^3 \cdot (1-p)^{n-3} \\
# &\approx 25,03\%
# \end{align*}
# $$

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# P(X\leq 1) &= P(X=0) + P(X=1) \\
# &= (1-p)^n + \binom n1 \cdot p \cdot (1-p)^9 \\
# &\approx 30,03\%
# \end{align*}
# $$

# %% [markdown]
# ## S. 464
# ### Nr. 3.

# %% [markdown]
# $$
# \begin{align*}
# n &:= 6 \\
# p &:= \frac12
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# P(X=3) &= \binom 63 \cdot \frac1{2^6} \\
# &= 20 \cdot \frac1{64} \\
# &= \frac5{16}
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# P(X\geq 3) &= \sum_{i=3}^6 P(X=i) \\
# &= \frac5{16} + \frac1{2^6}\sum_{i=4}^6\binom 6i \\
# &= \frac{42}{64} \\
# &= \frac{21}{32}
# \end{align*}
# $$

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# P(X\leq 3) &= P(X\geq 3) \\
# &= \frac{21}{32}
# \end{align*}
# $$

# %% [markdown]
# ### 4.
# $$
# \begin{align*}
# n &:= 8 \\
# p &:= \frac13
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# P(X=4) &= \binom 84 \cdot \frac1{3^4} \cdot \frac{2^4}{3^4} \\
# &= \frac{8\cdot 7 \cdot 6 \cdot 5}{4 \cdot 3 \cdot 2} \cdot \frac1{81} \cdot \frac{16}{81} \\
# &\approx 0,171
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# P(X\geq 4) &= \sum_{i=4}^8 P(X=i) \\
# &\approx 0,259
# \end{align*}
# $$

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# P(X\leq 3) &= \sum_{i=0}^3 P(X=i) \\
# &\approx 0,741
# \end{align*}
# $$

# %% [markdown]
# #### d.
# $$
# \begin{align*}
# P(X>4) &= \sum_{i=5}^8 P(X=i) \\
# &\approx 0,088
# \end{align*}
# $$
