# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 423
# ### Nr. 1.

# %% [markdown]
# a. Mit: $\displaystyle \frac{16}{49} $ Ohne: $\displaystyle \frac{2}{7} $
#
# b. Mit: $\displaystyle \frac{24}{49} $ Ohne: $\displaystyle \frac{4}{7} $
#
# c. Mit: $\displaystyle \frac{40}{49} $ Ohne: $\displaystyle \frac{6}{7} $
#
# d. Mit: $\displaystyle \frac{40}{49} $ Ohne: $\displaystyle \frac{6}{7} $

# %% [markdown]
# ### Nr. 3.

# %% [markdown]
# #### a.
# $\displaystyle P(kkk) = \frac1{64} $
#
# Es wird mindestens ein Patient geheilt.

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# P(hkk) + P(khk) + P(kkh) &= \frac9{64}
# \end{align*}
# $$
#
# Zwei, drei oder keine Patienten werden geheilt.

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# P(hhk) + P(hkh) + P(khh) &= \frac{27}{64}
# \end{align*}
# $$
#
# Es werden nicht exakt zwei Patienten geheilt.

# %% [markdown]
# #### d.
# $$
# \begin{align*}
# 1-P(hhh) &= \frac{37}{64}
# \end{align*}
# $$
#
# Alle Patienten werden geheilt.

# %% [markdown]
# ### Nr. 4.
# $E$|$P(E)$
# :-:|:-:
# $ 1 $|$\displaystyle \frac{11}{36} $
# $ 2 $|$\displaystyle \frac{9}{36} $
# $ 3 $|$\displaystyle \frac{7}{36} $
# $ 4 $|$\displaystyle \frac{5}{36} $
# $ 5 $|$\displaystyle \frac{3}{36} $
# $ 6 $|$\displaystyle \frac{1}{36} $

# %% [markdown]
# ## S. 424
# ### Nr. 5.
# $$
# \begin{align*}
# E &= \left\{ x|x\in\Omega,\, \sum x \leq 3 \right\} \\
# F &= \left\{ 11; 21; 31; 41 \right\}
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $\displaystyle E = \left\{ 11; 12; 21 \right\} $

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# P(E) &= \frac{2^2}{6^2} + 2\frac26\frac16 \\
# &= \frac{2}{9} \\
# P(F) &= 2\frac{2^2}{6^2} + 2\frac26\frac16 \\
# &= \frac{1}{3} \\
# P(E \cap F) &= P(21) + P(11) \\
# &= \frac16
# \end{align*}
# $$

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# P(E \cup F) &= P(E) + P(F) - P(E\cap F) \\
# &= \frac29 + \frac13 - \frac16 \\
# &= \frac{7}{8}
# \end{align*}
# $$

# %% [markdown]
# ### Nr. 7.
# #### a.
# $$
# \begin{align*}
# 1 - \left(\frac56\right)^5
# \end{align*}
# $$

# %%
Eq(Symbol("P"), (1-Rational(5,6)**5).evalf())
# Out:
# P = 0.598122427983539

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# P &= \frac{5!}{6^4}
# \end{align*}
# $$

# %%
Eq(Symbol("P"), (5*4*3*2/6**4))
# Out:
# P = 0.0925925925925926

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# P &= \left( \frac56 \right)^4 \frac16
# \end{align*}
# $$

# %%
Eq(Symbol("P"), (Rational(5,6)**4 * Rational(1,6)).evalf())
# Out:
# P = 0.0803755144032922

# %% [markdown]
# ### Nr. 8.
# #### a.
# $\displaystyle P = 0,485 $
#
# #### b.
# $\displaystyle P = 0,515 $

# %%
[
    0.515**4 * 0.485,
    0.485**4 * 0.515
]
# Out:
# [0.034116985803125006, 0.028495362321875]

# %% [markdown]
# ### Nr. 9.
# #### a.
# $\displaystyle P = \frac{1}{13.983.816} $

# %%
Eq(Symbol("P"), Rational(1,13983816).evalf()*100*Symbol("~\\%"))
# Out:
# P = 7.15112384201852e-6⋅~\%

# %% [markdown]
# #### b.
# $\displaystyle P = \frac{49-5}{13.983.816} = \frac{11}{3495454} $

# %%
Eq(Symbol("P"), Rational(44,13983816).evalf()*100*Symbol("~\\%"))
# Out:
# P = 0.000314649449048815⋅~\%

# %% [markdown]
# #### c.
# $\displaystyle P = \frac{43! \cdot 43!}{37! \cdot 49!} $

# %%
Eq(Symbol("P"), (factorial(43)*factorial(43)/(factorial(37)*factorial(49))).evalf()*100*Symbol("~\\%"))
# Out:
# P = 43.5964975511692⋅~\%

# %% [markdown]
# ### 10.

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# P(\text{Zerfall}) &= 0,15 \\
# n(t) &= 100\% \cdot (1-0,15)^{t \cdot 1 \text{ d}^{-1}} \\
# n(10 \text{ d}) &= 0,85^{10}
# \end{align*}
# $$

# %%
Eq(Function("n")(10 * Symbol("\\text{ d}")), (Rational(85,100)**10).evalf()*100*Symbol("~\\%"))
# Out:
# n(10⋅\text{ d}) = 19.6874404340723⋅~\%

# %% [markdown]
# $$
# \begin{align*}
# n(t_h) &= 0,5 \\
# \rightarrow 0,85^{t_h \cdot 1 \text{ d}^{-1}} &= 0,5 \\
# \rightarrow t_h &= \log_{0,85}(0,5) \cdot 1 \text{ d}
# \end{align*}
# $$

# %%
Eq(Symbol("t_h"), log(Rational(5,10), Rational(85,100)).evalf()*Symbol("\\text{ d}"))
# Out:
# tₕ = 4.26502428179873⋅\text{ d}

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# t_h &:= 8 \text{ d} \\
# \rightarrow n(8 \text{ d}) &= 0,5 \\
# &= (1-P(\text{Zerfall}))^8 \\
# \rightarrow P(\text{Zerfall}) &= 1 - \frac{1}{\sqrt[8]2}
# \end{align*}
# $$

# %%
Eq(Function("P")(Symbol("\\text{Zerfall}")), (1-1/pow(2, Rational(1,8))).evalf()*100*Symbol("~\\%"))
# Out:
# P(\text{Zerfall}) = 8.29959567953288⋅~\%

# %% [markdown]
# ### Nr. 11.
# #### a.
# Schätzung 1: Vierer \
# Schätzung 2: Achter \
# Schätzung 3: Sechser

# %% [markdown]
# #### b.
