# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 436
# ### Nr. 5.

# %% [markdown]
# $~$|$U$|$\overline U$|$~$
# -|-|-|-
# $F$|$0,3$|$0,2$|$0,5$
# $\overline F$|$0,4$|$0,1$|$0,5$
# $~$|$0,7$|$0,3$|$1,0$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# P(U|F) &= \frac35 \\
# P(F|U) &= \frac37 \\
# \end{align*}
# $$

# %% [markdown]
# #### d.
#
# Die Wahrscheinlichkeit, dass eine Person weiblich ist und wöchentlich mehr als sieben Stunden Hausaufgaben macht, beträgt $0,3$. Die Wahrscheinlichkeit, dass eine Person weiblich ist und wöchentlich genau oder weniger als sieben Stunden Hausaufgaben macht, beträgt $0,2$.
#
# Die Wahrscheinlichkeit, dass eine Person nicht weiblich ist und wöchentlich mehr als sieben Stunden Hausaufgaben macht, beträgt $0,4$. Die Wahrscheinlichkeit, dass eine Person nicht weiblich ist und wöchentlich genau oder weniger als sieben Stunden Hausaufgaben macht, beträgt $0,1$.
#
# Die Wahrscheinlichkeit, dass eine Person weiblich ist, beträgt $0,5$. Die Wahrscheinlichkeit, dass eine Person wöchentlich mehr als sieben Stunden Hausaufgaben macht, beträgt $0,7$.

# %% [markdown]
# ### Nr. 6.

# %% [markdown]
# #### a.
# $~$|$A$|$B$|ges.
# -|-|-|-
# $K$|$0,24$|$0,12$|$0,36$
# $L$|$0,16$|$0,48$|$0,64$
# ges.|$0,4$|$0,6$|$1$

# %% [markdown]
# #### c.
# ##### Ursprüngliches Baumdiagramm
#
# Zufallsexperiment: Zweimaliges Ziehen aus einer Urne mit zwei blauen und drei roten Kugeln; wenn eine blaue Kugel gezogen wird, wird sie zurückgelegt, wenn aber eine rote Kugel gezogen wird, wird sie nicht zurückgelegt.
#
# Ereignis $A$: Es wird eine blaue Kugel gezogen. \
# Ereignis $B$: Es wird eine rote Kugel gezogen. \
# $K = A; L = B$
#
# ##### Invertiertes Baumdiagramm
#
# $$
# \begin{align*}
# P(K) &= 0,36 \\
# P(L) &= 0,64 \\
# P(A|K) &= \frac23 \\
# P(B|K) &= \frac13 \\
# P(A|L) &= \frac14 \\
# P(B|L) &= \frac34
# \end{align*}
# $$
#
# Zufallsexperiment: Zweimaliges Ziehen aus einer Urne mit zwei blauen und einer roten Kugel mit Zurücklegen; wenn eine blaue Kugel gezogen wird, wird eine blaue Kugel durch zwei rote ersetzt.
#
# Ereignis $L$: Es wird eine blaue Kugel gezogen. \
# Ereignis $K$: Es wird eine rote Kugel gezogen. \
# $A=L; B=K$

# %% [markdown]
# ## Nr. 10.

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# P_A(J) &= \frac{7}{9} \\
# P_J(A) &= \frac{7}{56} \\
# &= \frac18
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# P_B(J) &= \frac{30}{51} \\
# &= \frac{5}{8}
# \end{align*}
# $$

# %% [markdown]
# ## S. 440
# ### Nr. 3.
# $$
# \begin{align*}
# \Omega &:= \set{a_1;a_2;a_3;h_1;h_2}^2 \\
# E &:= \set{(a,b)|(a,b)\in\Omega,\, a\in \set{a_1;a_2;a_3}}
# \end{align*}
# $$
#
# #### a.
# $$
# \begin{align*}
# F &:= \set{(a,b)|(a,b)\in\Omega,\, b\in \set{a_1;a_2;a_3}} \\
# P(E\cap F) &= P(E) \cdot P(F) \\
# E\cap F &= \set{a_1;a_2;a_3}^2 \\
# P(E\cap F) &= \frac{ \left| E\cap F \right| }{ \left| \Omega \right| } \\
# &= \frac{ 3^2 }{ 5^2 } \\
# &= \frac{9}{25} \\
# P(E) \cdot P(F) &= P(\set{a_1;a_2;a_3} \times \set{a_1;a_2;a_3;h_1;h_2})^2 \\
# &= \left(\frac{3 \cdot 5}{25}\right)^2 \\
# &= \frac{225}{625} \\
# &= \frac{45}{125} \\
# &= \frac{9}{25} \\
# &= P(E\cap F) \\
# &\rightarrow \text{stochastisch unabhängig}
# \end{align*}
# $$
#
# #### b.
# F: Kein Buchstabe kommt zweimal vor
#
# $$
# \begin{align*}
# E\cap F &= \set{(a,b)|(a,b)\in\Omega,\,a\in\set{a_1;a_2;a_3},\,b\in\set{h_1;h_2}} \\
# P(F) &= \frac35 \cdot \frac25 \cdot 2 \\
# &= \frac{12}{25} \\
# P(E\cap F) &= \frac{ \left| \set{a_1;a_2;a_3} \times \set{h_1;h_2} \right| }{ \left| \Omega \right| } \\
# &= \frac{6}{25} \\
# &\neq P(E) \cdot P(F),~  \left| E \right| \neq \frac12 \left| \Omega \right| \implies P(E) \neq \frac12 \\
# &\rightarrow \text{stochastisch abhängig}
# \end{align*}
# $$
#
# #### c.
# $$
# \begin{align*}
# P(F_a|E) &= P(F) = \frac{3}{5} \\
# P(E|F_a) &= P(E) = \frac{3}{5} \\
# P(F_b|E) &= \frac{P(E\cap F_b)}{P(E)} = \frac{2}{5} \\
# P(E|F_b) &= \frac{P(E\cap F_b)}{P(F_b)} = \frac{1}{2}
# \end{align*}
# $$
