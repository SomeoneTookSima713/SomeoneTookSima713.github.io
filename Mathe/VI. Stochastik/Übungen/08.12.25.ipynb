# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $$
# \begin{align*}
# \Omega &:= \set{1;2;3;4;5;6} \\
# A &:= \set{1;2;5} \\
# B &:= \set{2;5;6}
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# A \cup B &= \set{1;2;5;6} \\
# A \cap B &= \set{2;5} \\
# B \setminus A &= \set{6} \\
# \Omega \setminus B &= \set{1;3;4} \\
# (A\cup B)\setminus(A\cap B) &= A\triangle B = \set{1;6} \\
# \Omega \setminus (A\cup B) &= \set{3;4}
# \end{align*}
# $$

# %% [markdown]
# ## LB. S. 433
# ### Nr. 1.

# %% [markdown]
# a. $\displaystyle P(\text{gerade} \cup \set{6}) = P(\text{gerade}) = \frac12 $

# %% [markdown]
# b. $\displaystyle P(\text{nicht gerade} \cup \complement\set{6}) = P(\complement\set{6}) = \frac56 $

# %% [markdown]
# ## S. 453
# ### Nr. 2.
#
# $~$|Mo.|Di. - Fr.|ges.
# -|-|-|-
# ohne Mängel|$180$|$768$|$948$
# mit Mängeln|$20$|$32$|$52$
# ges.|$200$|$800$|$1000$

# %% [markdown]
# a. $\displaystyle P(\text{mit Mängeln}) = \frac{52}{1000} = 5,2\% $
#
# b. $\displaystyle P(\text{mit Mängeln}|\text{Mo.}) = \frac{20}{200} = 10\% $
#
# c. $\displaystyle P(\text{Mo.}|\text{mit Mängeln}) = \frac{20}{52} \approx 38,5\% $

# %% [markdown]
# ## S. 456
# ### Nr. 3.
# $~$|Junge|Mädchen|ges.
# -|-|-|-
# mit Instrument|$5$|$9$|$14$
# ohne Instrument|$15$|$3$|$18$
# ges.|$20$|$12$|$32$
#
# $\displaystyle P(\text{Mädchen}|\text{mit Instrument}) = \frac9{14} \approx 64,3\% $

# %% [markdown]
# ## Abituraufgabe
#
# $~$|mit Farbanstrich|ohne Farbanstrich|ges.
# -|-|-|-
# Selbstaufbau|$25\%$|$5\%$|$30\%$
# Komplettmontage|$55\%$|$15\%$|$70\%$
# ges.|$80\%$|$20\%$|$100\%$

# %% [markdown]
# ### 5.
# $\displaystyle P(A) = 70\% $
#
# $\displaystyle P(B) = 25\% $

# %% [markdown]
# ### 7.
# $\displaystyle P(\text{Komplettmontage}|\text{ohne Farbanstrich}) = \frac{15\%}{20\%} = 75\% $

# %% [markdown]
# ## Abituraufgabe 2

# %% [markdown]
# #### a.
#
# $~$|$B$|$\overline B$|ges.
# -|-|-|-
# $A$|$p$|$2p$|$3p$
# $\overline A$|$3p$|$1-6p$|$1-3p$
# ges.|$4p$|$1-4p$|$1$
#
# $\displaystyle 1-\frac65 < 1 $
