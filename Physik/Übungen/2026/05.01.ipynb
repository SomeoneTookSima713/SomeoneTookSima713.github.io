# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 441
# ### Nr. 4.
# #### b.
# $$
# \begin{align*}
# P(A) &= 25\% \\
# P(B) &= 50\% \\
# P(C) &= 25\%
# \end{align*}
# $$

# %% [markdown]
# ## S. 442
# ### Nr. 12.

# %% [markdown]
# #### a.
# * je bestimmter der Ort, desto unbestimmter der Impuls und umgekehrt

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# \Delta x \cdot \Delta p &= \frac{h}{4\pi} \\
# \rightarrow \Delta x(\Delta p) &= \frac{h}{2\pi\Delta p}
# \end{align*}
# $$

# %%
plt.plot([n/100 for n in range(1,101)], [(Eval.planck_constant/(2*pi*n/100)).evalf() for n in range(1,101)])
plt.ylabel("Δx in m")
plt.xlabel("Δp in ms⁻¹")
# plt.axis((0, 1e-32, 0, 1))
plt.grid(true, "major", "both", color='#888888', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# \Delta p &= \pm 1 \frac{\text{mm}}{\text s} \cdot 500 \text{ g} \\
# &= \pm \frac{1}{2000} \frac{\text m}{\text s} \\
# \Delta x \cdot \Delta p &\geq \frac{h}{4\pi} \\
# \Delta p &> 0 \\
# \rightarrow \Delta x &\geq \frac{h}{4\pi\Delta p}
# \end{align*}
# $$

# %%
GreaterThan(Symbol("\\Delta x"), (Eval.planck_constant/(4*pi*Rational(1,2000))).evalf())
# Out:
# \Delta x ≥ 1.05457181764616e-31
