# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $$
# \begin{align*}
# L &:= 1,48 \text{ nm} \\
# E_n &= \frac{h^2}{8L^2m_e} \cdot n^2
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# E_{\text{ph}} &= E_2-E_1 \\
# \end{align*}
# $$

# %%
n = Symbol("n")
E = Eval.planck_constant**2 / (8*1.48e-9**2*Eval.mass.electron)*n**2

((E.subs(n, 2)-E.subs(n, 1)) / Eval.elementary_charge).evalf() * Symbol("\\text{ eV}")
# Out:
# 0.515072529826917⋅\text{ eV}

# %%
(Eval.planck_constant * Eval.light_speed / ((E.subs(n, 2)-E.subs(n, 1)))).evalf() * 1e9 * Symbol("\\text{ nm}")
# Out:
# 2407.38656316143⋅\text{ nm}
