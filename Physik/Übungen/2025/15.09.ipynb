# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $$
# \begin{align*}
# v &= \frac{50 \text{ m}}{40 \text{ s}} \\
# &= 1,25 \frac{\text m}{\text s} \\
# \lambda &= \frac{v}{f} \\
# &= \frac{1,25 \frac{\text m}{\text s}}{0,3 \text{ Hz}} \\
# &= \frac{25}6 \text{ m}
# \end{align*}
# $$
