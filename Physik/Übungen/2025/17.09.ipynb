# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $$
# \begin{align*}
# y(x, t) &= 0,02\sin\left( \frac\pi4t\cdot 1\frac1{\text s} - 10\pi x\cdot1\frac1{\text m} \right)\,,~ y\text{ in m} \\
# \end{align*}
# $$

# %%
def y(x, t):
    return Rational(2,100)*sin(pi/4*t - 10*pi*x)

Eq(Function("y")(0.5, 40), y(0.5, 40).evalf())
# Out:
# y(0.5, 40) = 0

# %% [markdown]
# ## LB. S. 171
# ### Nr. 14
# $$
# \begin{align*}
# y(0, t) &= 3 \text{ cm} \cdot \sin\left(\frac{3\pi}{3 \text{ s}} t\right) \\
# v &\colonequals 5 \frac{\text m}{\text s}
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# \hat y &= 3\text{ cm} \\
# T &= 2 \text{ s} \\
# f &= 0,5 \text{ Hz} \\
# \lambda &= v \cdot T \\
# &= 10 \text{ m}
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# y(x, t) &= 3 \text{ cm} \cdot \sin\left( 2\pi\left( 0,5 \text{ Hz}\cdot t - \frac{x}{10 \text{ m}} \right) \right)
# \end{align*}
# $$

# %%
plt.plot([i/50 for i in range(100)], [0.03 * sin(2*pi*(0.5*i/50)).evalf() for i in range(100)])
plt.ylabel("y in Metern")
plt.xlabel("t in Sekunden")
# plt.axis((0, 2, 0, 0.8))
plt.grid(true, "major", "both", color='#888888', linestyle='--', linewidth=0.5)
plt.show()

plt.plot([i/20 for i in range(200)], [0.03 * sin(2*pi*(i/200)).evalf() for i in range(200)])
plt.ylabel("y in Metern")
plt.xlabel("x in Metern")
# plt.axis((0, 2, 0, 0.8))
plt.grid(true, "major", "both", color='#888888', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# y(x, t) &= 3 \text{ cm} \cdot \sin\left( 2\pi\left( 0,5 \text{ Hz}\cdot t - \frac{x}{10 \text{ m}} \right) \right)
# \end{align*}
# $$

# %% [markdown]
# ## LB. S. 172
# ### Nr. 16

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# \hat y &= 1 \text{ mm} \\
# f &= 500 \text{ Hz} \\
# \lambda &= 0,6 \text{ m} \\
# T &= 2 \text{ ms}
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# y(x,t) &= 1 \text{ mm} \cdot \sin\left( 2\pi\left( 500 \text{ Hz} \cdot t - \frac{x}{0,6 \text{ m}} \right) \right)
# \end{align*}
# $$

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# y(0,4 \text{ m}; t) &= 1 \text{ mm} \cdot \sin\left(2\pi\left( 500 \text{ Hz} \cdot t - \frac23 \right)\right)
# \end{align*}
# $$

# %% [markdown]
# ---

# %% [markdown]
# $$
# \begin{align*}
# v &\colonequals 3,0 \frac{\text m}{\text s} \\
# \hat y &\colonequals 0,1 \text{ m} \\
# f &\colonequals 0,25 \text{ Hz} \\
# \rightarrow T &= 4 \text{ s}
# \end{align*}
# $$

# %% [markdown]
# #### a.
# $$
# \begin{align*}
# \lambda &= v\cdot T \\
# &= 12 \text{ m}
# \end{align*}
# $$

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# t &= \frac{120 \text{ m}}{3 \frac{\text m}{\text s}} \\
# &= 40 \text{ s}
# \end{align*}
# $$

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# y(x, t) &= 0,1 \text{ m} \cdot \sin\left( 2\pi\left( 0,25 \text{ Hz} \cdot t - \frac{x}{12 \text{ m}} \right) \right)
# \end{align*}
# $$

# %% [markdown]
# #### d.

# %%
y_d = 0.1*sin(2*pi*(0.25*50 - 120/12)).evalf()

Eq(Function("y")(120, 50), y_d.evalf())
# Out:
# y(120, 50) = 0
