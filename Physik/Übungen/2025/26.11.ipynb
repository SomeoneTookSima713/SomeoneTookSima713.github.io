# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $$
# \begin{align*}
# E_\text{kin}(f) &= hf - W_A \\
# \rightarrow U(f) &= -\frac{hf - W_A}{e} \\
# \rightarrow U(\lambda) &= -\frac{hc - W_A\lambda}{e\lambda} \\
# \end{align*}
# $$
