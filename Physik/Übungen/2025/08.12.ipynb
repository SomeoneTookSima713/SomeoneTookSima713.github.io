# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $$
# \begin{align*}
# \lambda &= \frac{h}{\sqrt{2m_eU_B}} \\
# &= \frac{dR}{L} \\
# &= 2d\sin\alpha \\
# \tan2\alpha &= \frac{D}{2L} \\
# L &:= 125 \text{ mm} \\
# D_1 &:= 28 \text{ mm} \\
# D_2 &:= 48 \text{ mm}
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# d &= \frac{\lambda}{2\sin\alpha} \\
# &= \frac{\lambda}{2\sin\left( \frac12\arctan \left(\frac12DL^{-1}\right) \right)}
# \end{align*}
# $$
