# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## Abituraufgabe
# ### 1.
#
# * Annahme, Elektron als Teilchen:
#     * Doppelspalt erzeugt Schattenbild auf Aufnahmeschirm
# * Experimentelle Beobachtung: Interferenzmuster
#     * entsteht durch Aussenden von zwei Huygensschen Wellen an Spalten, die miteinander interferrieren
#
#         → Experiment zeigt, dass Elektronen Welleneigenschaften aufweisen können

# %% [markdown]
# ### 2.
# #### a.
# $$
# \begin{align*}
# \sin\alpha &= \frac{k\lambda}{d} \\
# &= \frac{1\cdot5\cdot10^{-12} \text{ m}}{2,0\cdot10^{-6} \text{ m}} \\
# \rightarrow \alpha &= \arcsin \left( 2,5\cdot10^{-6} \right)
# \end{align*}
# $$

# %%
Eq(Symbol("\\alpha"), (asin(Rational(5,2)*1e-6) * 180 / pi).evalf()*Symbol("\\degree"))
# Out:
# \alpha = 0.000143239448782855⋅\degree

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# \tan\alpha &= \frac{s_k}{e} \\
# \rightarrow \tan\left( \arcsin\left( 2,5\cdot10^{-6} \right) \right) &= \frac{s_1}{350\cdot10^{-3} \text{ m}} \\
# \rightarrow s_1 &= 350\cdot10^{-3} \text{ m} \cdot \tan\left( \arcsin\left( 2,5\cdot10^{-6} \right) \right) \\
# \end{align*}
# $$

# %%
Eq(Symbol("s_1"), (Rational(350,1000)*tan(asin(Rational(5,2)*1e-6))).evalf() * Symbol("\\text{ m}"))
# Out:
# s₁ = 8.75000000002734e-7⋅\text{ m}

# %% [markdown]
# Wie an der Rechnung zu erkennen ist, weisen die Maxima 1. Ordnung zu dem 0. Ordnung einen Abstand auf dem Leuchtschirm von ca. $8,75\cdot10^{-7} \text{ m}$ auf. Nach 100-facher elektronenoptischer und 10-facher lichtoptischer Vergrößerung beträgt dieser Abstand also rund $8,75\cdot10^{-4} \text{ m}$ und liegt demnach im dreistelligen Mikrometerbereich. Damit sind die Maxima visuell voneinander unterscheidbar und mit dem bloßen Auge beobachtbar.

# %% [markdown]
# #### c.
# $$
# \begin{align*}
# E_\text{kin} &= U_Be \\
# \rightarrow v &= \sqrt{ \frac{2U_Be}{m} } \\
# \lambda &= \frac{h}{m\cdot v} \\
# &= \frac{h}{\sqrt{2mU_Be}} \\
# \rightarrow \lambda &\sim \frac1{\sqrt{U_B}}
# \end{align*}
# $$
#
# * Bescheunigungsspannung wird erhöht
# * De Broglie-Wellenlänge wird kleiner (siehe Proportionalität oben)
# * Größenordnung Spalt entfernt sich noch mehr von Wellenlänge (siehe Text: Spalt schon so viel größer als Wellenlänge von Elektronen)
# * Beugungseffekte werden kleiner
# * Interferenzmuster wird kleiner

# %% [markdown]
# #### d.
# * jede Geschwindigkeit fungiert wie ein eigener Elektronenstrahl (erzeugt eigenes Interferenzmuster)
#
#     → Überlagerung vieler Interferenzmuster

# %% [markdown]
# ### 3.
# #### a.
# Da hab ich Niklas geholfen, die hab ich also praktisch gemacht

# %% [markdown]
# #### b.
