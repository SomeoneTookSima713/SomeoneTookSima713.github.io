# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# ## LB. S. 172
# ### Nr. 19.

# %% [markdown]
# #### b.
# $$
# \begin{align*}
# \Delta x &= \sqrt{x^2 + s^2} - x \\
# \Delta \varphi &= \arcsin\frac{\Delta x}{\lambda} \\
# &= \arcsin\frac{\sqrt{x^2 + s^2} - x}{\lambda} \\
# &= \arcsin\frac{f\left(\sqrt{x^2 + s^2} - x\right)}{v} \\
# \rightarrow f &= \frac{v\sin\left( \Delta\varphi \right)}{\sqrt{x^2 + s^2} - x}
# \end{align*}
# $$

# %%
Eq(Symbol("f"), (340*0.5/(sqrt(Rational(14,10)**2 + Rational(7,10)**2)-Rational(14,10))).evalf())
# Out:
# f = 1028.75936596423
