# %%
# Init the environment
import sys
import schemdraw
import schemdraw.elements as schemelem
import matplotlib
import matplotlib.pyplot as plt
import numpy
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $$
# \begin{align*}
# \omega_{0,1} &= 2\pi\frac\pi8 \frac d{l^2}\left(n - \frac12\right)^2 \sqrt{\frac E{\varrho}} \\
# \omega_{0,2} &= 1,015\frac{T}{L^2} \sqrt{\frac E{\varrho}}
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# E &\colonequals 200.000.000.000 \frac{\text N}{\text m^2} \\
# \varrho &\colonequals 8000 \frac{\text{kg}}{\text m^3} \\
# d &\colonequals 0,005 \text{ m} \\
# l &\colonequals 0,55 \text{ m}
# \end{align*}
# $$

# %%
E = Integer(6000) * Integer(1000000)
rho = Integer(8000)
d = Rational(5, 1000)
l = Rational(550, 1000)

Eq(Symbol("\\omega_{0,1}"), (2*pi*pi/8*d/l**2*(-Rational(1,2))**2*sqrt(E/rho)).evalf())
# Out:
# \omega_{0,1} = 8.82988443868397
