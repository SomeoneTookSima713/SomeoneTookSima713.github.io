# %%
# Init the environment
import sys
import matplotlib
import matplotlib.pyplot as plt
sys.path.insert(0, "../../..")

from init_physics_env import *

# %% [markdown]
# $\displaystyle 2\text{Al} + 6\text{HCl} \rightarrow 2\text{AlCl}_3 + 3\text{H}_2 $
#
# $\displaystyle Q = -51,62 \text{ kJ} $

# %% [markdown]
# $\displaystyle Q_m = \frac{Q}{n_\text{Fu}} $
#
# $\displaystyle 1\text{Al} + 3\text{HCl} \rightarrow 1\text{AlCl}_3 + \frac32\text{H}_2 $

# %% [markdown]
# $$
# \begin{align*}
# n_\text{Fu} &= \frac{m_\text{Al}}{M_\text{Al}} \\
# \rightarrow Q_m &= \frac{QM_\text{Al}}{m_\text{Al}} \\
# &= \frac{-51,62 \text{ kJ} \cdot 27 \frac{\text g}{\text{mol}}}{3,25 \text{ g}} &= -428,8 \frac{\text{kJ}}{\text{mol}}
# \end{align*}
# $$

# %% [markdown]
# ---

# %% [markdown]
# $\displaystyle \text{CaC}_2 + 2\text{H}_2\text{O} \rightarrow \text{Ca}(\text{OH})_2 + \text C_2 \text H_2 $
#
# $$
# \begin{align*}
# T &= 0 ~\degree\text C \\
# p &= 101,325 \text{ kPa} \\
# W_m &= -p\Delta V \cdot 1 ~\frac1{\text{mol}} \\
# \Delta V &= 22,4 \frac{\text l}{\text{mol}} \cdot 1 \\
# \end{align*}
# $$

# %%
Eq(Symbol("W_m"), -101.325 * 22.4 /1000 * Symbol("\\frac{\\text {kJ}}{\\text{mol}}"))
# Out:
# Wₘ = -2.26968⋅\frac{\text {kJ}}{\text{mol}}
